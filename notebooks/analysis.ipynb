# %%
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/maia-sh/intovalue-data/main/data/processed/trials.csv"
data = pd.read_csv(url)

# %%
data
# Out:
#                 id            registry  is_resolved  iv_version  \
# 0      NCT00742495  ClinicalTrials.gov         True           1
# 1      NCT00003636  ClinicalTrials.gov         True           1
# 2      NCT00020566  ClinicalTrials.gov         True           1
# 3      NCT00047112  ClinicalTrials.gov         True           1
# 4      NCT00052468  ClinicalTrials.gov         True           1
# ...            ...                 ...          ...         ...
# 3785  DRKS00007860                DRKS         True           2
# 3786  DRKS00008914                DRKS         True           2
# 3787  DRKS00008832                DRKS         True           2
# 3788  DRKS00010175                DRKS         True           2
# 3789  DRKS00013008                DRKS         True           2
#
#      identification_step  is_dupe  iv_completion  iv_status  \
# 0           Dissertation    False           True       True
# 1        Registry linked    False          False       True
# 2        Registry linked    False          False       True
# 3        Registry linked    False           True       True
# 4        Registry linked    False           True       True
# ...                  ...      ...            ...        ...
# 3785             No publ    False           True       True
# 3786             No publ    False           True       True
# 3787             No publ    False           True       True
# 3788             No publ    False           True       True
# 3789             No publ    False           True       True
#
#       iv_interventional  has_german_umc_lead  ...  \
# 0                  True                False  ...
# 1                  True                False  ...
# 2                  True                 True  ...
# 3                  True                False  ...
# 4                  True                False  ...
# ...                 ...                  ...  ...
# 3785               True                 True  ...
# 3786               True                 True  ...
# 3787               True                 True  ...
# 3788               True                 True  ...
# 3789               True                 True  ...
#
#                      licenses_required permission_issuer embargo  \
# 0                                  NaN               NaN     NaN
# 1                                   []           journal     6.0
# 2           [{'type': 'other-closed'}]         publisher    12.0
# 3                                   []         publisher     NaN
# 4     [{'type': 'cc-by', 'terms': ''}]           article     NaN
# ...                                ...               ...     ...
# 3785                               NaN               NaN     NaN
# 3786                               NaN               NaN     NaN
# 3787                               NaN               NaN     NaN
# 3788                               NaN               NaN     NaN
# 3789                               NaN               NaN     NaN
#
#      date_embargo_elapsed is_embargo_elapsed permission_accepted  \
# 0                     NaN                NaN                 NaN
# 1              2011-03-02               True               False
# 2              2015-08-10               True                True
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 3785                  NaN                NaN                 NaN
# 3786                  NaN                NaN                 NaN
# 3787                  NaN                NaN                 NaN
# 3788                  NaN                NaN                 NaN
# 3789                  NaN                NaN                 NaN
#
#      permission_published  is_oa  is_archivable is_closed_archivable
# 0                     NaN    NaN            NaN                  NaN
# 1                    True   True           True                  NaN
# 2                    True  False           True                 True
# 3                     NaN  False            NaN                  NaN
# 4                     NaN   True            NaN                  NaN
# ...                   ...    ...            ...                  ...
# 3785                  NaN    NaN            NaN                  NaN
# 3786                  NaN    NaN            NaN                  NaN
# 3787                  NaN    NaN            NaN                  NaN
# 3788                  NaN    NaN            NaN                  NaN
# 3789                  NaN    NaN            NaN                  NaN
#
# [3790 rows x 106 columns]

# %%
sns.set_theme(style="darkgrid")
sns.countplot(x="registry", data=data, label="test", color="b")
# Out:
# <AxesSubplot:xlabel='registry', ylabel='count'>
